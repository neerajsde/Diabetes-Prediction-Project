# %% [markdown]
# **Importing required libraries**

# %%
# Importing necessary libraries for data analysis and visualization
import numpy as np                     # For numerical operations
import pandas as pd                    # For data manipulation and analysis
import matplotlib.pyplot as plt        # For creating plots and visualizations
# %matplotlib inline
import seaborn as sns                  # For making statistical graphics

# %% [markdown]
# Explanation of libraries:
# - `numpy` is a fundamental package for scientific computing with Python. It provides support for large, multi-dimensional arrays and matrices, along with a collection of mathematical functions to operate on these arrays.
# - `pandas` is a popular data manipulation library that provides data structures like DataFrame and Series, making data analysis more convenient and efficient.
# - `matplotlib.pyplot` is a plotting library that provides a MATLAB-like interface for creating static, animated, and interactive visualizations in Python.
# - `%matplotlib inline` is a magic command used in Jupyter notebooks to display plots directly in the notebook, without needing to call `plt.show()`.
# - `seaborn` is a high-level interface for drawing attractive and informative statistical graphics, built on top of matplotlib.

# %% [markdown]
# **Load Dataset**

# %%
# Reading the dataset into a pandas DataFrame
df = pd.read_csv('diabetes_prediction_dataset.csv')

# %% [markdown]
# Explanation:
# - `pd.read_csv()` is a function provided by the pandas library that allows us to read data from a CSV (Comma-Separated Values) file and store it as a DataFrame.
# - In this specific case, we are reading a CSV file named 'diabetes_prediction_dataset.csv' and storing its contents in the variable 'df'.
# - The DataFrame 'df' can be used for further data analysis and manipulation tasks.
# - Make sure that the CSV file 'diabetes_prediction_dataset.csv' is present in the current working directory or provide the appropriate file path if it's located elsewhere.

# %% [markdown]
# **Dimensions of the dataframe**

# %%
# Checking the dimensions of the DataFrame 'df'
df.shape
# Out:
# (100000, 9)

# %% [markdown]
# Explanation:
# - The `shape` attribute of a DataFrame in pandas returns a tuple representing the dimensions of the DataFrame.
# - The first element of the tuple represents the number of rows, and the second element represents the number of columns in the DataFrame.
# - By assigning `df.shape` to the variable `shape`, we can access and use these dimensions later in the code.
# - For example, you can print `shape` to see the number of rows and columns in the DataFrame.

# %%
print('Number of observations :',df.shape[0])
print('Number of variables    :',df.shape[1])
# Out:
# Number of observations : 100000
# Number of variables    : 9

# %% [markdown]
# **Information about the schema**

# %%
# Displaying the first few rows of the DataFrame 'df'
df.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %% [markdown]
# Explanation:
# - The `head()` function of a DataFrame in pandas is used to retrieve the first few rows of the DataFrame.
# - By default, it returns the first 5 rows, but you can specify the number of rows to display by passing an argument to the function (e.g., `df.head(10)` to display the first 10 rows).
# - Assigning `df.head()` to the variable `df_head` allows us to store and use this subset of data for further examination or preview.
# - This is particularly useful when dealing with large datasets, as it helps to quickly inspect the data and get a sense of its content and structure.
# - Note that using `df.head()` will not modify the original DataFrame 'df', it will only create a temporary view of the first few rows.

# %%
# Displaying the last few rows of the DataFrame 'df'
df.tail()
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 99995          6.2                   90         0
# 99996          6.5                  100         0
# 99997          5.7                  155         0
# 99998          4.0                  100         0
# 99999          6.6                   90         0

# %%
# Retrieving the column names of the DataFrame 'df'
df.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'smoking_history',
#        'bmi', 'HbA1c_level', 'blood_glucose_level', 'diabetes'],
#       dtype='object')

# %% [markdown]
# Explanation:
# - The `columns` attribute of a DataFrame in pandas returns a list of column names present in the DataFrame.
# - By assigning `df.columns` to the variable `columns_list`, we can access and use this list for further data analysis or manipulation.
# - For example, you can iterate through the column names, perform specific operations on each column, or use them as references for selecting particular columns.
# - Having the column names readily available is essential for understanding the data structure and conducting meaningful analyses.
# - Note that the order of column names in the `columns_list` will match the order of columns in the DataFrame 'df'.
# - If you need the column names as a regular Python list, you can convert it using `list(df.columns)`.

# %%
# Generating descriptive statistics for the DataFrame 'df'
df.describe()
# Out:
#                  age  hypertension  heart_disease            bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# ...

# %% [markdown]
# Explanation:
# - The `describe()` function of a DataFrame in pandas computes various summary statistics for each numerical column in the DataFrame.
# - The statistics include count (number of non-null values), mean (average), standard deviation, minimum value, 25th percentile (1st quartile), 50th percentile (median or 2nd quartile), 75th percentile (3rd quartile), and maximum value.
# - The `describe()` function is incredibly helpful in understanding the distribution and central tendencies of the data.
# - The resulting DataFrame `df_summary` will have column-wise statistics, with the column names as the index of the DataFrame.
# - Note that `describe()` only provides statistics for numerical columns. Non-numeric columns (e.g., object, string) are excluded from the summary.
# - If needed, you can separately analyze non-numeric columns using specific methods appropriate for their data types.

# %%
# Generating descriptive statistics for object (string) columns in the DataFrame 'df'
df_object_summary = df.describe(include='object')

# %%
# Calculating the number of missing values in each column of the DataFrame 'df'
df.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %% [markdown]
# Explanation:
# - The `isnull()` function of a DataFrame in pandas is used to create a boolean DataFrame of the same shape as the original, where each element is True if it is a missing value (NaN), and False otherwise.
# - The `sum()` function is then applied to the boolean DataFrame to count the number of True values (missing values) in each column.
# - The resulting Series `missing_values_count` contains the count of missing values for each column, with column names as the index of the Series.
# - This provides a quick summary of the data quality and helps identify columns with missing values that may require further attention or handling.
# - Having insight into the missing data is crucial for making informed decisions about data imputation or understanding the potential impact on data analysis.

# %%
# Converting data types of specific columns in the DataFrame 'df'
df.age = df.age.astype(int)
df.diabetes = df.diabetes.astype('category')
df.hypertension = df.hypertension.astype('category')
df.heart_disease = df.heart_disease.astype('category')

# %% [markdown]
# Explanation:
# - The `astype()` function in pandas is used to convert the data type of a Series (column) to a specified data type.
# - In the first line, `df.age.astype(int)` converts the 'age' column to the integer data type.
# - In the subsequent lines, the `astype()` function is used to convert the 'diabetes', 'hypertension', and 'heart_disease' columns to the 'category' data type.
# - The 'category' data type is useful when dealing with categorical variables that have a fixed set of unique values, as it can save memory and allow for more efficient operations.
# - After applying the `astype()` function, the columns in the DataFrame 'df' will have the new specified data types.
# - It's important to ensure that the conversion is done correctly, and the data in the columns are compatible with the new data types.
# - If the conversion is not possible (e.g., due to invalid data in the column), it may raise an error, so it's a good practice to check the data beforehand.

# %%
# Displaying a concise summary of the DataFrame 'df'
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  int32
#  2   hypertension         100000 non-null  category
#  3   heart_disease        100000 non-null  category
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  category
# dtypes: category(3), float64(2), int32(1), int64(1), object(2)
# memory usage: 4.5+ MB

# %%
# Counting the number of unique values in each column of the DataFrame 'df'
df.nunique()
# Out:
# gender                    3
# age                      81
# hypertension              2
# heart_disease             2
# smoking_history           6
# bmi                    4247
# HbA1c_level              18
# blood_glucose_level      18
# diabetes                  2
# dtype: int64

# %%
# Removing rows with gender as 'Other' from the DataFrame 'df'
df = df[~df.gender.isin(['Other'])]

# %%
# Retrieving the unique values in the 'gender' column of the DataFrame 'df'
df.gender.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
# Creating a figure with two subplots to visualize the distribution of the 'gender' variable
plt.figure(figsize=(20, 6))
sns.set_style('darkgrid')
plt.suptitle('Distribution of Gender Variable', fontsize=20)

# Subplot 1 - Pie Chart
plt.subplot(1, 2, 1)
df['gender'].value_counts().plot(kind='pie', autopct='%.2f', shadow=True)
plt.title('Pie Chart')

# Subplot 2 - Bar Plot
plt.subplot(1, 2, 2)
ax = sns.countplot(x='gender', data=df, palette='Set2')
ax.bar_label(ax.containers[0])
plt.title('Bar Plot')

plt.show()

# %%
# Creating a figure with two subplots to visualize the distribution of the 'diabetes' variable
plt.figure(figsize=(20, 6))
sns.set_style('darkgrid')
plt.suptitle('Distribution of Diabetes Variable', fontsize=20, color='green')

# Subplot 1 - Pie Chart
plt.subplot(1, 2, 1)
df['diabetes'].value_counts().plot(kind='pie', autopct='%.1f', fontsize=15)
plt.title('Pie Chart')

# Subplot 2 - Bar Plot
plt.subplot(1, 2, 2)
ax = sns.countplot(x=df.diabetes)
ax.bar_label(ax.containers[0])
plt.xlabel('Diabetes', fontsize=15, color='red')
plt.ylabel('Counts', fontsize=15, color='red')
plt.title('Bar Plot')

plt.show()

# %%
def distribution_chart(df, feature):
    """
    Creates distribution charts for specified columns in the DataFrame.

    Parameters:
        df (DataFrame): The DataFrame containing the data.
        feature (list): List of column names to visualize their distributions.

    Returns:
        None (Displays distribution charts for each specified feature.)
    """
    for column in feature:
        # Creating a figure with two subplots to visualize the distribution of the current 'column'
        plt.figure(figsize=(18, 6))
        sns.set_style('darkgrid')
        plt.suptitle(f"Distribution of {column} Variable", fontsize=20)

        # Subplot 1 - Histogram with KDE (Kernel Density Estimate)
        plt.subplot(1, 2, 1)
        sns.histplot(df[column], kde=True)
        plt.axvline(x=df[column].mean(), color='red', alpha=0.5, label='Mean')
        plt.axvline(x=df[column].median(), ls='--', color='blue', alpha=0.5, label='Median')
        plt.legend()
        plt.xlabel(column)

        # Subplot 2 - Box Plot
        plt.subplot(1, 2, 2)
        sns.boxplot(x=df[column])
        plt.xlabel(column)

        plt.show()

# %%
# Selecting columns with numeric data types from the DataFrame 'df'
num_var = df.select_dtypes('number').columns
num_var
# Out:
# Index(['age', 'bmi', 'HbA1c_level', 'blood_glucose_level'], dtype='object')

# %% [markdown]
# Explanation:
# - The `select_dtypes()` function of a DataFrame in pandas is used to select columns based on their data types.
# - When `select_dtypes('number')` is used, it selects only those columns that have numeric data types, such as integers and floating-point numbers.
# - The `columns` attribute is then used to retrieve the names of the selected columns as a list.
# - The resulting list `num_var` contains the names of columns that contain numerical data, which can be used for further analysis or visualization tasks.
# - This is useful when you have a mix of numeric and non-numeric columns in the DataFrame and want to focus only on the numerical ones for specific operations.

# %%
# Using the function to visualize the distribution of numerical variables in the DataFrame 'df'
num_var = df.select_dtypes('number').columns
distribution_chart(df, num_var)

# %%
def detect_outliers(df, column):
    # Step 1: Extract the column values and sort them in ascending order
    column_values = df[column].values
    column_values_sorted = np.sort(column_values)
    
    # Step 2: Calculate the first quartile (Q1) and third quartile (Q3)
    q1, q3 = np.percentile(column_values_sorted, [25, 75])
    
    # Step 3: Calculate the Interquartile Range (IQR)
    iqr = q3 - q1
    
    # Step 4: Calculate the lower and upper fences to identify outliers
    lower_fence = q1 - 1.5 * iqr
    upper_fence = q3 + 1.5 * iqr
    
    # Step 5: Identify outliers in the column based on the lower and upper fences
    outliers = [value for value in column_values if value < lower_fence or value > upper_fence]
    
    # Step 6: Return the list of identified outliers
    return outliers

# %%
# Assuming you have already defined the 'detect_outliers()' function

# Detect outliers in each column
age_outliers = detect_outliers(df, 'age')
bmi_outliers = detect_outliers(df, 'bmi')
HbA1c_outliers = detect_outliers(df, 'HbA1c_level')
blood_glucose_outliers = detect_outliers(df, 'blood_glucose_level')

# Remove outliers from the DataFrame
df = df[~df['age'].isin(age_outliers)]
df = df[~df['bmi'].isin(bmi_outliers)]
df = df[~df['HbA1c_level'].isin(HbA1c_outliers)]
df = df[~df['blood_glucose_level'].isin(blood_glucose_outliers)]

# The DataFrame 'df' now contains the data with outliers removed from each column.

# %%
# Resetting the index of the DataFrame 'df' and dropping the existing index
df = df.reset_index(drop=True)

# %% [markdown]
# Explanation:
# - The `reset_index()` function of a DataFrame in pandas is used to reset the DataFrame's index.
# - When `drop=True` is specified, the existing index is dropped and replaced with a new sequential integer index, starting from 0.
# - The new index reflects the order of the rows in the DataFrame after the reset.
# - Resetting the index is useful when the current index is not meaningful or when it needs to be reset to the default sequential index.
# - After resetting the index, the DataFrame 'df' will have a new index, and the previous index will be removed from the DataFrame.
# - This operation is often used to remove any gaps in the index or to start the index from 0, particularly after performing data manipulations that may have changed the order of the rows.
# - The 'drop=True' argument ensures that the old index is not added to the DataFrame as a new column, avoiding redundant information.

# %%
# Checking the updated shape of the DataFrame 'df'
df.shape
# Out:
# (90370, 9)

# %%
# Counting the number of unique values in each column of the DataFrame 'df' after resetting the index
df.nunique()
# Out:
# gender                    2
# age                      81
# hypertension              2
# heart_disease             2
# smoking_history           6
# bmi                    2380
# HbA1c_level              16
# blood_glucose_level      15
# diabetes                  2
# dtype: int64

# %%
# Calculating and printing the mean, median, and skewness for each numerical variable in the DataFrame 'df'
print('----------- Mean -----------')
print(df[num_var].mean())
print()

print('---------- Median -----------')
print(df[num_var].median())
print()

print('---------- Skewness -----------')
# Calculating skewness for each numerical variable and plotting it as a bar plot
ax = df[num_var].skew().plot(kind='bar')
ax.bar_label(ax.containers[0])
print()
# Out:
# ----------- Mean -----------
# age                     41.400033
# bmi                     26.317339
# HbA1c_level              5.456331
# blood_glucose_level    134.571661
# dtype: float64
#
# ---------- Median -----------
# age                     42.00
# bmi                     27.32
# HbA1c_level              5.80
# blood_glucose_level    140.00
# dtype: float64
#
# ---------- Skewness -----------

# %% [markdown]
# **Outcome with other features**

# %%
def outcome_features(df, features, x_var='diabetes'):
    """
    Creates a pair of bar plots for specified features in the DataFrame 'df' based on the variable 'x_var'.

    Parameters:
        df (DataFrame): The DataFrame containing the data.
        features (list): List of column names to be visualized.
        x_var (str): The variable to compare the features with (default: 'diabetes').

    Returns:
        None (Displays the pair of bar plots for each specified feature).
    """
    for column in features:
        # Creating a figure with two subplots to visualize the features based on 'x_var'
        plt.figure(figsize=(8, 4))
        sns.set_style('darkgrid')
        plt.suptitle(f"{column} Variable")

        # Subplot 1 - Bar Plot with bar labels
        plt.subplot(1, 2, 1)
        ax = sns.barplot(x=x_var, y=column, data=df)
        ax.bar_label(ax.containers[0])
        plt.title(f"{column} by {x_var}")

        # Subplot 2 - Another Bar Plot (similar to Subplot 1) with bar labels
        plt.subplot(1, 2, 2)
        ax = sns.barplot(x=x_var, y=column, data=df)
        ax.bar_label(ax.containers[0])
        plt.title(f"{column} by {x_var}")

        plt.show()

# %%
# Using the function to visualize the numerical variables based on the 'diabetes' variable
outcome_features(df, num_var)

# %%
# Selecting only the numerical columns from the DataFrame 'df' and creating DataFrame 'df2'
df2 = df[num_var]

# Creating a figure and a heatmap to visualize the Spearman correlation matrix
plt.figure(figsize=(13, 6))
sns.heatmap(df2.corr(method='spearman').round(2), annot=True, vmin=-1, vmax=1)
plt.show()

# %%
# Creating a pair plot of scatter plots for numerical variables, colored by the 'diabetes' variable
sns.pairplot(data=df, hue='diabetes')
plt.show()
# Out:
# C:\Users\neera\AppData\Roaming\Python\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# **Export dataset**

# %%
# Saving the DataFrame 'df' as a CSV file named 'clean_dataset_diabetes.csv' without including the index
df.to_csv('clean_dataset_diabetes.csv', index=False)

# %% [markdown]
# Explanation:
# - The `to_csv()` function is used to save the DataFrame 'df' as a CSV (Comma-Separated Values) file.
# - The first argument 'clean_dataset_diabetes.csv' specifies the name of the CSV file to be created.
# - The second argument 'index=False' ensures that the DataFrame's index is not included in the CSV file.
# - If 'index=True' were used, the index would be saved as an additional column in the CSV file.
# - By setting 'index=False', the CSV file will only contain the data from the DataFrame 'df'.
# - The CSV file will be saved in the current working directory (the location where the Python script or Jupyter Notebook is running).
# - The saved CSV file can be later loaded back into a DataFrame using the `pd.read_csv()` function in pandas.

# %% [markdown]
# **Models with their results**

# %%
# Creating feature variables (X) and the target variable (y) for machine learning tasks

# Dropping columns 'gender', 'smoking_history', and 'diabetes' to form the feature variables (X)
X = df.drop(['gender', 'smoking_history', 'diabetes'], axis=1)

# Assigning the target variable 'diabetes' to y
y = df['diabetes']

# %% [markdown]
# Explanation:
# - The DataFrame 'df' contains both the feature variables (input variables) and the target variable (output variable).
# - The 'drop()' function is used to create the feature variables (X) by removing specific columns from the DataFrame.
# - The 'axis=1' parameter indicates that the columns will be dropped (axis=0 is for rows).
# - The 'drop()' function is used to remove the columns 'gender', 'smoking_history', and 'diabetes' from the DataFrame,
#   creating the feature variables X, which will contain all the other columns from the original DataFrame.
# - The 'X' DataFrame now contains all the features except the columns 'gender', 'smoking_history', and the target variable 'diabetes'.
# - The target variable 'diabetes' is assigned to the variable 'y' by selecting only the 'diabetes' column from the DataFrame 'df'.
# - Now, 'X' contains the feature variables (input features), and 'y' contains the target variable (output variable).
# - This format is suitable for many machine learning algorithms, where 'X' is used to train the model, and 'y' is used for prediction or evaluation.
# - The specific columns dropped in 'X' depend on the problem and what you want to achieve with the machine learning model.

# %%
# Standardizing the feature variables in 'X' using the StandardScaler

# Importing the StandardScaler from scikit-learn
from sklearn.preprocessing import StandardScaler

# Creating a StandardScaler object
sc = StandardScaler()

# Using the StandardScaler object to standardize the feature variables in 'X'
x = sc.fit_transform(X)

# %%
# Splitting the standardized feature variables 'x' and the target variable 'y' into training and testing sets

# Importing the train_test_split function from scikit-learn
from sklearn.model_selection import train_test_split

# Using train_test_split to split 'x' and 'y' into training and testing sets
# test_size=0.1 specifies that 10% of the data will be used for testing, and 90% will be used for training
# random_state=0 sets the random seed for reproducibility, ensuring the same split is obtained on each run
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=0)

# %%
# Importing performance metrics from scikit-learn

# Accuracy Score: Evaluates the accuracy of classification models by comparing predicted labels to true labels.
from sklearn.metrics import accuracy_score

# Classification Report: Provides a comprehensive report including precision, recall, F1-score, and support for each class in a classification task.
from sklearn.metrics import classification_report

# Confusion Matrix: Evaluates the performance of a classification model by showing the counts of true positive, false positive, true negative, and false negative predictions.
from sklearn.metrics import confusion_matrix

# R-squared Score (R2 Score): Evaluates the goodness-of-fit of regression models, indicating how well the model fits the observed data.
from sklearn.metrics import r2_score

# Mean Squared Error (MSE): Evaluates the performance of regression models by measuring the average squared difference between predicted and true values.
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # 1. Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression
reg = LogisticRegression()
reg.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = reg.predict(x_test)
print('-----------------------------------------------------')
print('Classification Report is : ↴\n',classification_report(y_test, y_pred))
print('-----------------------------------------------------')
print('Confusion Metrix : ↴\n',confusion_matrix(y_test, y_pred))
print('-----------------------------------------------------')
print('\tTraining Score : ', str(round(reg.score(x_train, y_train)*100, 1))+'%')
print('-----------------------------------------------------')
print('\tMean Square Error : ',str(round(mean_squared_error(y_test, y_pred)*100, 2))+'%')
print('-----------------------------------------------------')
print('\tR2 score is : ',str(round(r2_score(y_test,y_pred)*100,2))+'%')
print('-----------------------------------------------------')
# Out:
# -----------------------------------------------------
# Classification Report is : ↴
#                precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      8582
#            1       0.75      0.38      0.50       455
#
#     accuracy                           0.96      9037
#    macro avg       0.86      0.68      0.74      9037
# weighted avg       0.96      0.96      0.96      9037
#
# -----------------------------------------------------
# Confusion Metrix : ↴
#  [[8525   57]
#  [ 284  171]]
# -----------------------------------------------------
# 	Training Score :  96.4%
# -----------------------------------------------------
# 	Mean Square Error :  3.77%
# -----------------------------------------------------
# 	R2 score is :  21.08%
# -----------------------------------------------------

# %%
reg_score = round(accuracy_score(y_test, y_pred)*100,2) # getting score
print(str(reg_score)+'%')
# Out:
# 96.23%

# %% [markdown]
# # 2. Decision Tree Model

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier(max_depth=6, random_state=123, criterion='entropy')
dtree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=6, random_state=123)

# %%
y_pred = dtree.predict(x_test)
print('-----------------------------------------------------')
print('Classification Report is : ↴\n',classification_report(y_test, y_pred))
print('-----------------------------------------------------')
print('Confusion Metrix : ↴\n',confusion_matrix(y_test, y_pred))
print('-----------------------------------------------------')
print('\tTraining Score : ', str(round(dtree.score(x_train, y_train)*100, 1))+'%')
print('-----------------------------------------------------')
print('\tMean Square Error : ',str(round(mean_squared_error(y_test, y_pred)*100, 2))+'%')
print('-----------------------------------------------------')
print('\tR2 score is : ',str(round(r2_score(y_test,y_pred)*100,2))+'%')
print('-----------------------------------------------------')
# Out:
# -----------------------------------------------------
# Classification Report is : ↴
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      8582
#            1       1.00      0.51      0.67       455
#
#     accuracy                           0.98      9037
#    macro avg       0.99      0.75      0.83      9037
# weighted avg       0.98      0.98      0.97      9037
#
# -----------------------------------------------------
# Confusion Metrix : ↴
#  [[8582    0]
#  [ 224  231]]
# -----------------------------------------------------
# 	Training Score :  97.4%
# -----------------------------------------------------
# 	Mean Square Error :  2.48%
# -----------------------------------------------------
# 	R2 score is :  48.16%
# -----------------------------------------------------

# %%
dt_score = round(accuracy_score(y_test, y_pred)*100,2) # getting score
print(str(dt_score)+'%')
# Out:
# 97.52%

# %% [markdown]
# # 3. Random Forest Model

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rfc.predict(x_test)
print('-----------------------------------------------------')
print('Classification Report is : ↴\n',classification_report(y_test, y_pred))
print('-----------------------------------------------------')
print('Confusion Metrix : ↴\n',confusion_matrix(y_test, y_pred))
print('-----------------------------------------------------')
print('\tTraining Score : ', str(round(rfc.score(x_train, y_train)*100, 1))+'%')
print('-----------------------------------------------------')
print('\tMean Square Error : ',str(round(mean_squared_error(y_test, y_pred)*100, 2))+'%')
print('-----------------------------------------------------')
print('\tR2 score is : ',str(round(r2_score(y_test,y_pred)*100,2))+'%')
print('-----------------------------------------------------')
# Out:
# -----------------------------------------------------
# Classification Report is : ↴
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      8582
#            1       0.82      0.53      0.65       455
#
#     accuracy                           0.97      9037
#    macro avg       0.90      0.76      0.82      9037
# weighted avg       0.97      0.97      0.97      9037
#
# -----------------------------------------------------
# Confusion Metrix : ↴
#  [[8530   52]
#  [ 212  243]]
# -----------------------------------------------------
# 	Training Score :  99.7%
# -----------------------------------------------------
# 	Mean Square Error :  2.92%
# -----------------------------------------------------
# 	R2 score is :  38.9%
# -----------------------------------------------------

# %%
rfc_score = round(accuracy_score(y_test, y_pred)*100,2) # getting score
print(str(rfc_score)+'%')
# Out:
# 97.08%

# %% [markdown]
# # 4. K Neighbour Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
y_pred = knn.predict(x_test)
print('-----------------------------------------------------')
print('Classification Report is : ↴\n',classification_report(y_test, y_pred))
print('-----------------------------------------------------')
print('Confusion Metrix : ↴\n',confusion_matrix(y_test, y_pred))
print('-----------------------------------------------------')
print('\tTraining Score : ', str(round(knn.score(x_train, y_train)*100, 1))+'%')
print('-----------------------------------------------------')
print('\tMean Square Error : ',str(round(mean_squared_error(y_test, y_pred)*100, 2))+'%')
print('-----------------------------------------------------')
print('\tR2 score is : ',str(round(r2_score(y_test,y_pred)*100,2))+'%')
print('-----------------------------------------------------')
# Out:
# -----------------------------------------------------
# Classification Report is : ↴
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      8582
#            1       0.91      0.42      0.57       455
#
#     accuracy                           0.97      9037
#    macro avg       0.94      0.71      0.78      9037
# weighted avg       0.97      0.97      0.96      9037
#
# -----------------------------------------------------
# Confusion Metrix : ↴
#  [[8564   18]
#  [ 266  189]]
# -----------------------------------------------------
# 	Training Score :  97.1%
# -----------------------------------------------------
# 	Mean Square Error :  3.14%
# -----------------------------------------------------
# 	R2 score is :  34.27%
# -----------------------------------------------------

# %%
knn_score = round(accuracy_score(y_test, y_pred)*100,2) # getting score
print(str(knn_score)+'%')
# Out:
# 96.86%

# %%
# Printing the accuracy scores of different machine learning models

# 'reg_score', 'dt_score', 'rfc_score', and 'knn_score' are variables that hold the accuracy scores of different models.
# These variables are assumed to have been computed previously by evaluating the respective models on the test data.

# Printing the accuracy scores for each model in a formatted table.
print('-------- Accuracy Table --------')
print()
print('Logistic Regression : ', reg_score)
print()
print('Decision Tree       : ', dt_score)
print()
print('Random Forest       : ', rfc_score)
print()
print('K Neighbors         : ', knn_score)
print()
print('-------- -------------- --------')
# Out:
# -------- Accuracy Table --------
#
# Logistic Regression :  96.23
#
# Decision Tree       :  97.52
#
# Random Forest       :  97.08
#
# K Neighbors         :  96.86
#
# -------- -------------- --------

# %% [markdown]
# - our Decision Tree hs highest percentage od accuracy of almost 97.52 % .
# - next is by random forest nearly same as 96.96 % .
# - followed by Logistic Regression and K Neighbors both are almost same as 96.23 % and 96.86 % .

# %% [markdown]
# # End

# %% [markdown]
# **Contact me** <br>
# Portfolio: https://neerajpandit2023.github.io/Portfolio/  <br>
# LinkedIn: https://www.linkedin.com/in/neerajpandit75/  <br>
# Github: https://github.com/NeerajPandit2023
